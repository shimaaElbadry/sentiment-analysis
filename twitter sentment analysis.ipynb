# %%
import tweepy
from tweepy import Stream                                   
from tweepy.streaming import StreamListener                 
from tweepy import OAuthHandler
import codecs
from string import punctuation
from flask import Flask, render_template, request

app = Flask(__name__)

@app.route("/")
def hello():
    return render_template("ner.html",lang="",ner="")

@app.route("/sentiment")
# The consumer key, consumer secret, access token and access secret should
# be obtained from the Twitter UI when registering an application
ckey = 'JjqU6C81ZSFttww8Xe2lWXrCg'
csecret = '7MQDARYlC3f7sX5TlstvEHI3BYVjTOiFvRtoiu8fpb5NjBSwny'
atoken = '835019765508788224-Twx0VMQM48xsdDV0OQ4Q1ZjGdmGrOTt'
asecret = 'N950rLZolhw3I1RLhzujjnqZXTRdu8yueS5HVoL62XLHh'

# OAuth Authentication
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

# Twitter API wrapper
api = tweepy.API(auth)

# Load the list of positive and negative words
# These will be used for analysing the tweets
pos_sent = open("positive-words.txt").read()
positive_words = pos_sent.split('\n')

neg_sent = open('negative-words.txt').read()
negative_words = neg_sent.split('\n')

# tweetSearch() searches for 100 tweets containing the "Celebrity name"
# and saves them to "testTweets.txt" for sentiment analysis at
# tweetSentimentAnalysis
def tweetSearch(celebrityName):

    outFile = codecs.open("testTweets.txt", 'w', "utf-8")
    results = api.search(q=celebrityName, lang="en", locale="en", count=100)

    for result in results:
        outFile.write(result.text + '\n')

    outFile.close()

#the core of the analysis logic
# count the total number
# of positive and negative words cumulated across all the
# tweets stored in "testTweets.txt" and decide the sentiment.
def posNegCount(tweet):

    pos = 0
    neg = 0

    for p in list(punctuation):
        tweet = tweet.replace(p, '')

    tweet = tweet.lower() #.encode('utf8')
    words = tweet.split(' ')
    word_count = len(words)

    for word in words:
        if word in positive_words:
            pos = pos + 1
        elif word in negative_words:
            neg = neg + 1

    return pos, neg

def tweetSentimentAnalysis():
    
    outFile = codecs.open("testTweetsLineByLine.txt", 'w', "utf-8")
    # Read all the tweets from "testTweets.txt" and 
    # split + store them to tweets_list
    tweets = codecs.open("testTweets.txt", 'r', "utf-8").read()
    tweets_list = tweets.split('\n')
    #tweets.close()           - AttributeError: 'str' object has no attribute 'close'

    positive_counter = 0
    negative_counter = 0

    # Call posNegCount() on each tweet stored in tweets_list and
    # increment positive_counter and negative_counter accordingly
    for idx, tweet in enumerate(tweets_list):
        if(len(tweet)):
            p, n = posNegCount(tweet)
            positive_counter += p
            negative_counter += n
            temp = p - n 
            dataToBeSaved = "tweet with idx : --- {}  --- \n , have the following postivity : {} \n\n".format(tweet, temp)
            print(dataToBeSaved)
            outFile.write(dataToBeSaved)
            
    outFile.close()
    #print("positive_counter:", positive_counter, "negative_counter:", negative_counter)

    # Hopefully, this is self-explanatory
    if positive_counter > negative_counter:
        return "POSITIVE"

    elif positive_counter < negative_counter:
        return "NEGATIVE"

    else:
        return "NEUTRAL"

a=tweetSearch("vodafone")
tweetSentimentAnalysis()
# Out:
# tweet with idx : --- RT @sonyxperiagb: Get Hotel Transylvania 1&amp;2 on Blu-Ray FREE when you buy an #Xperia L1 or XA1 exclusively at @VodafoneUK. Purchase today a…  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- @maxpowered @VodafoneUK Can’t even call Vodafone numbers saying calls to them are restricted aswell x  ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- @alicegowerxxx @VodafoneUK Oh how queer. Perhaps you should contact Vodafone and just ask what's going on and c if… https://t.co/5VoBcQmxJv  ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- What's your dream job? 👩‍🌾👨🏻‍🚀 — Vodafone is my dream❤🌸 https://t.co/nx3RNEmZC3  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- RT @Survey54_: How much do you spend on airtime &amp; data bundles each month? #Ghana #MTN #Vodafone #Airtel #Glomobile #Africa #Data #Emerging…  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- RT @Survey54_: How much do you spend on airtime &amp; data bundles each month? #Ghana #MTN #Vodafone #Airtel #Glomobile #Africa #Data #Emerging…  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- @warisofficial We'd love to hear from you https://t.co/xNSKRMZQH7  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- RT @Survey54_: How much do you spend on airtime &amp; data bundles each month? #Ghana #MTN #Vodafone #Airtel #Glomobile #Africa #Data #Emerging…  ---
#  , have the following postivity : 0
#
#
# tweet with idx : ---
---
#  , have the following postivity : 1
#
#
# tweet with idx : --- @VodafoneUK Yeah before today Ross, gutted! 🙈  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- How about a ‘pity me’ Alexa Amazon for a veteran Vodafone customer for over a decade?! 🤫😉👍  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- RT @SioneSnow: Called Vodafone today so they ask to confirm my first name so I say Sione and they ask me how to spell it so I say S for Sio…  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- RT @JoeyBruqz: You can never lose your connection with God, whether you feel like it’s there or not.   ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- Just like not having bundle doesn’t…  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- @officialpes @hakanc10 where is the vodafone park  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- @VodafoneIN Please call on the alternate number which is given to you because I am not using that Vodafone sim from… https://t.co/IFeSDQNwHz  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- @alicegowerxxx @VodafoneUK Have ya called Vodafone customer service  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- RT @modise_setoaba: Send @vodafone tilbake if they don't listen. S.A. is ours and our laws are binding. If you're racist voetsek here. #ple…  ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- @VodafoneUK Would you please ask Vodafone Egypt to stop the repeated credit withdrawal unjustly from customers &amp; to… https://t.co/ZoTKVdbvtW  ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- @KapindraVerma We'd love to hear from you https://t.co/HqLLmqTqNM  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- @savvykapoor We'd love to hear from you https://t.co/jlE10wlU04  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- False alarm. I’m blaming Vodafone. https://t.co/I3IR0e9Oxy  ---
#  , have the following postivity : -2
#
#
# tweet with idx : --- @hmortada Would you please refresh the network setting  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- options - network options - network selection - manual   ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- then… https://t.co/v6eyzSkTPv  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- Send @vodafone tilbake if they don't listen. S.A. is ours and our laws are binding. If you're racist voetsek here. #pleasecallme #paynkosana  ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- @JioCare @reliancejio @JioCare @ConsumrConxion @TRAI   ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- I am done with jio and i request govt. to inform me and ppl's… https://t.co/V2KFLj30Zc  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- RT @TheAdClub_India: Vodafone’s @sidbanerjee13 showing us how to leverage a digital-led integrated campaign based on consumer insights deri…  ---
#  , have the following postivity : 2
#
#
# tweet with idx : --- My #MastersOfAnima #Review is now live:  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- https://t.co/1Pcvlz90Nr~  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- @evolve_pr @terminalsio @BastionPR… https://t.co/rbRErMClc1  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- @hmortada Do you know if there is any other Vodafone number facing the same issue in the same place or not ?  ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- ^HN  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- RT @VodafoneVGE: Should we be afraid of robots? No, not really. They are here to help, via @RWW https://t.co/oynWkJInXn https://t.co/O7pkaz…  ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- @ThreeCare @ThreeIreland All over Kildare pretty much. Leixlip, blackwood, clane, parts of Maynooth. The reason I'm… https://t.co/vASzxnZWo8  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- @VodafoneIN Ashmed of you Vodafone. Very disappointing with internet speed. It is 2kbps in Kathihar Junction.   ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- I wo… https://t.co/zRecoURzvv  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- I liked a @YouTube video https://t.co/CddVAoPkiW MULTIPLAYER GAMEPLAY WITH AIRTEL, JIO, VODAFONE COMPARISON | HINDI |  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- #Telematics can be used to improve driver performance and safety and even save police lives, says @PoliceOne https://t.co/kfVRCimOfA  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- Just been told by @VodafoneUK that they are unable to contact @OpenreachHelp and that I must do this myself. Vodafo… https://t.co/ZLVpEW6LSx  ---
#  , have the following postivity : -1
#
#
# tweet with idx : --- @VodafoneIN @VodafoneIN_News @Vodafone_CEO @DoT_India Utterly disappointed by the twitter handle @VodafoneIN for no… https://t.co/jlnOxwTqwZ  ---
#  , have the following postivity : -2
#
#
# tweet with idx : --- 80% of #customers said that they would spend more with companies that give them a good customer experience. Discove… https://t.co/bpy2UjZv6T  ---
#  , have the following postivity : 1
#
#
# tweet with idx : --- Vodafone's drone, the Wingcopter XBR sets Guinness World Record https://t.co/5SCe85glUg https://t.co/ZxY5kHWemx  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- Vodafone with the theivery  ---
#  , have the following postivity : 0
#
#
# tweet with idx : --- RT @Ryanbabel: New vlog online, wee keep them coming : https://t.co/Xfz3pF911U  ---
#  , have the following postivity : 0
# 'POSITIVE'
